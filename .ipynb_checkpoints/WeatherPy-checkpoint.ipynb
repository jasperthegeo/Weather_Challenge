# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# There is almost no relationship between wind speed an latitude; wind speed relies more on geography and landscape features than lattitude; ie forested areas are not windy because the forests break in the winds; but coastal areas and plains are windy because of constantly changing pressure systems.
#
# There is a relationship of sorts between humidity and latitude, but that seems to be most within the northern landmasses as opposed to the southern. This is due to the fact that since the majority of the landmass is in the northern hemisphere, the vast majority of perceieved humidity in the air will be there.
#
# There is a definitive relationship between latitudes and temperature... the arctic and antarctic are cold, and frozen (for now anyway...)
#
# ---
#
# #### Note
# * TEMPERATURES ARE IN Celcius!! NOT FAHRENHEIT... THIS ISN'T 1820! USE METRIC

# %%
#!pip install citipy - once completed no longer need

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import urllib.parse
from pprint import pprint
import scipy.stats as st

# Import API key
import api_keys
api_key = api_keys.api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
cities
# Out:
# ['cabo san lucas',
#  'sur',
#  'ust-maya',
#  'svetlogorsk',
#  'lorengau',
#  'kloulklubed',
#  'san patricio',
#  'azangaro',
#  'narsaq',
#  'northam',
#  'tuktoyaktuk',
#  'iskateley',
#  'ushuaia',
#  'kenai',
#  'cape town',
#  'albany',
#  'arraial do cabo',
#  'norman wells',
#  'san juan',
#  'bredasdorp',
#  'punta arenas',
#  'zenzeli',
#  'codrington',
#  'saint-francois',
#  'taolanaro',
#  'lompoc',
#  'makasar',
#  'luganville',
#  'terrasini',
#  'singleton',
#  'nemuro',
#  'mahebourg',
#  'vaini',
#  'attawapiskat',
#  'barrow',
#  'mataura',
#  'pechenga',
#  'hermanus',
#  'sembe',
#  'new norfolk',
#  'fortuna',
#  'butaritari',
#  'turayf',
#  'bailen',
#  'hobart',
#  'sibu',
#  'mys shmidta',
#  'rikitea',
#  'severo-kurilsk',
#  'puerto ayora',
#  'puri',
#  'bluff',
#  'vostok',
#  'angoram',
#  'asyut',
#  'upernavik',
#  'rawannawi',
#  'kapaa',
#  'tiksi',
#  'ostrovnoy',
#  'saint-philippe',
#  'miri',
#  'mayfield',
#  'port alfred',
#  'bambous virieux',
#  'oriximina',
#  'hofn',
#  'chuy',
#  'chagda',
#  'kahului',
#  'saint george',
#  'qaanaaq',
#  'east london',
#  'taoudenni',
#  'kaitangata',
#  'victoria',
#  'itarema',
#  'kuopio',
#  'palabuhanratu',
#  'sarangani',
#  'castro',
#  'nuuk',
#  'margate',
#  'namatanai',
#  'san quintin',
#  'pisco',
#  'kologriv',
#  'carnarvon',
#  'jibuti',
#  'nikolskoye',
#  'bajil',
#  'jamestown',
#  'illoqqortoormiut',
#  'belushya guba',
#  'aguimes',
#  'busselton',
#  'ballina',
#  'talnakh',
#  'marcona',
#  'venado tuerto',
#  'fujin',
#  'atuona',
#  'champerico',
#  'avarua',
#  'noumea',
#  'texarkana',
#  'kingston',
#  'longyearbyen',
#  'taburi',
#  'chiredzi',
#  'kodiak',
#  'tual',
#  'banjar',
#  'provideniya',
#  'nizhneyansk',
#  'zhenjiang',
#  'lebu',
#  'xuddur',
#  'phalaborwa',
#  'lagoa',
#  'galle',
#  'ponta do sol',
#  'san cristobal',
#  'port blair',
#  'djambala',
#  'kashi',
#  'cidreira',
#  'samusu',
#  'college',
#  'berlevag',
#  'nabire',
#  'tasiilaq',
#  'clyde river',
#  'kungurtug',
#  'weihai',
#  'amderma',
#  'alta floresta',
#  'kavaratti',
#  'bethel',
#  'cherskiy',
#  'ucluelet',
#  'pavilosta',
#  'constitucion',
#  'saskylakh',
#  'bandarbeyla',
#  'sosnovka',
#  'sentyabrskiy',
#  'jaque',
#  'mouzakion',
#  'ribeira grande',
#  'dunedin',
#  'verkhoyansk',
#  'tura',
#  'shache',
#  'hami',
#  'vitoria de santo antao',
#  'san luis',
#  'cairns',
#  'saldanha',
#  'bealanana',
#  'zemio',
#  'romilly-sur-seine',
#  'manali',
#  'krasnoselkup',
#  'vila franca do campo',
#  'bandiagara',
#  'nome',
#  'kirensk',
#  'dingle',
#  'kutum',
#  'khani',
#  'lata',
#  'saint-georges',
#  'porto novo',
#  'puerto colombia',
#  'mount isa',
#  'faanui',
#  'san jose',
#  'fairbanks',
#  'decatur',
#  'fort saint james',
#  'sitka',
#  'tubruq',
#  'touros',
#  'rizarion',
#  'isangel',
#  'hualmay',
#  'mehamn',
#  'mar del plata',
#  'khatanga',
#  'barentsburg',
#  'manokwari',
#  'hithadhoo',
#  'atar',
#  'saleaula',
#  'havre-saint-pierre',
#  'jiroft',
#  'tsihombe',
#  'ulladulla',
#  'opuwo',
#  'binodegahan',
#  'gambo',
#  'riyadh',
#  'svetlaya',
#  'nizhniy tsasuchey',
#  'vilyuysk',
#  'gambela',
#  'esperance',
#  'paranhos',
#  'poitiers',
#  'sakaiminato',
#  'sadon',
#  'ginda',
#  'honningsvag',
#  'saint-augustin',
#  'ilam',
#  'grand river south east',
#  'yabassi',
#  'ulagan',
#  'hilo',
#  'flinders',
#  'kavieng',
#  'port lincoln',
#  'talas',
#  'rocha',
#  'teya',
#  'tuatapere',
#  'oum hadjer',
#  'saint anthony',
#  'saurimo',
#  'namibe',
#  'qurayyat',
#  'khurba',
#  'coahuayana',
#  'georgetown',
#  'itupiranga',
#  'biak',
#  'burley',
#  'srednekolymsk',
#  'tomigusuku',
#  'chicama',
#  'vao',
#  'dekar',
#  'dubai',
#  'maragogi',
#  'berberati',
#  'pala',
#  'kabompo',
#  'henties bay',
#  'haines junction',
#  'merauke',
#  'yeppoon',
#  'thompson',
#  'glenwood springs',
#  'port elizabeth',
#  'irondequoit',
#  'manoel urbano',
#  'thinadhoo',
#  'boone',
#  'katsuura',
#  'makubetsu',
#  'salalah',
#  'saint-pierre',
#  'pevek',
#  'broome',
#  'bacuit',
#  'xunchang',
#  'pocone',
#  'richards bay',
#  'sabang',
#  'durango',
#  'ossora',
#  'xuzhou',
#  'paka',
#  'viking',
#  'urumqi',
#  'acapulco',
#  'ancud',
#  'caravelas',
#  'vestmannaeyjar',
#  'koumac',
#  'santa maria',
#  'labuhan',
#  'chokurdakh',
#  'san lawrenz',
#  'oussouye',
#  'naftah',
#  'novosil',
#  'son la',
#  'damghan',
#  'lusambo',
#  'sobolevo',
#  'kudahuvadhoo',
#  'aklavik',
#  'neiafu',
#  'port macquarie',
#  'konce',
#  'ise',
#  'roald',
#  'buftea',
#  'kruisfontein',
#  'novobiryusinskiy',
#  'lively',
#  'samarai',
#  'igarka',
#  'kyshtovka',
#  'anadyr',
#  'quatre cocos',
#  'la ronge',
#  'nushki',
#  'chivay',
#  'kosa',
#  'male',
#  'moron',
#  'chaoyang',
#  'naze',
#  'sechura',
#  'soyo',
#  'sao filipe',
#  'tessalit',
#  'hay river',
#  'palmer',
#  'waingapu',
#  'huarmey',
#  'kurumkan',
#  'higuey',
#  'champoton',
#  'torbay',
#  'shiyan',
#  'lolua',
#  'benguela',
#  'souillac',
#  'swan hill',
#  'faya',
#  'tari',
#  'katha',
#  'salina cruz',
#  'griffith',
#  'thayetmyo',
#  'nara',
#  'krivosheino',
#  'tillabery',
#  'viedma',
#  'baglung',
#  'otradnoye',
#  'kualakapuas',
#  'dogondoutchi',
#  'vadlapudi',
#  'qaqortoq',
#  'sudzha',
#  'mixtepec',
#  'juigalpa',
#  'adrar',
#  'almeirim',
#  'hambantota',
#  'jalu',
#  'port hardy',
#  'puerto escondido',
#  'moose factory',
#  'geraldton',
#  'mahenge',
#  'vankleek hill',
#  'macia',
#  'scarborough',
#  'umzimvubu',
#  'akyab',
#  'guerrero negro',
#  'laguna',
#  'belen',
#  'obihiro',
#  'yakeshi',
#  'husavik',
#  'sheregesh',
#  'ilulissat',
#  'port augusta',
#  'hansi',
#  'ouesso',
#  'poum',
#  'tunduru',
#  'sabaudia',
#  'cururupu',
#  'mikuni',
#  'gat',
#  'bereda',
#  'kannad',
#  'puerto penasco',
#  'marsa matruh',
#  'coihaique',
#  'qabis',
#  'darnah',
#  'rungata',
#  'price',
#  'evensk',
#  'pangnirtung',
#  'tazovskiy',
#  'deh rawud',
#  'talaya',
#  'suluq',
#  'fort nelson',
#  'urdzhar',
#  'salinopolis',
#  'taltal',
#  'loralai',
#  'sao jose da coroa grande',
#  'morant bay',
#  'colares',
#  'wete',
#  'avera',
#  'luderitz',
#  'gizo',
#  'zyryanka',
#  'chandbali',
#  'plouzane',
#  'shirokiy',
#  'tommot',
#  'zholymbet',
#  'broken hill',
#  'santa rosa',
#  'nantucket',
#  'launceston',
#  'sol-iletsk',
#  'novyy urengoy',
#  'airai',
#  'chilca',
#  'malanje',
#  'kuche',
#  'zhangye',
#  'cayenne',
#  'camapua',
#  'high rock',
#  'chihuahua',
#  'bengkulu',
#  'karaul',
#  'garwa',
#  'fernley',
#  'meulaboh',
#  'abu kamal',
#  'enshi',
#  'urengoy',
#  'balikpapan',
#  'shingu',
#  'bosobolo',
#  'cascais',
#  'taybad',
#  'yenagoa',
#  'egvekinot',
#  'vardo',
#  'ati',
#  'hilton head island',
#  'vigrestad',
#  'zachagansk',
#  'hobyo',
#  'helong',
#  'ejutla de crespo',
#  'key largo',
#  'lavrentiya',
#  'beckley',
#  'san rafael',
#  'leningradskiy',
#  'borodino',
#  'vila do maio',
#  'dasoguz',
#  'simao',
#  'pokrovskoye',
#  'luorong',
#  'beyneu',
#  'gornyy',
#  'leshukonskoye',
#  'zaton',
#  'caconde',
#  'merke',
#  'goksun',
#  'iquitos',
#  'fontem',
#  'baijiantan',
#  'padang',
#  'aswan',
#  'thai nguyen',
#  'kholodnyy',
#  'alugan',
#  'mishan',
#  'kaohsiung',
#  'san nicola',
#  'yellowknife',
#  'ahuimanu',
#  'maghama',
#  'tabou',
#  'rorvik',
#  'concordia',
#  'miles city',
#  'loa janan',
#  'kaseda',
#  'karakol',
#  'belaya gora',
#  'ha giang',
#  'issoudun',
#  'diffa',
#  'maumere',
#  'bayan',
#  'barra patuca',
#  'novobirilyussy',
#  'sopelana',
#  'kopanskaya',
#  'andenes',
#  'bonavista',
#  'abilene',
#  'iqaluit',
#  'georgiyevka',
#  'akhmeta',
#  'mahajanga',
#  'hasaki',
#  'vila velha',
#  'hamilton',
#  'domoni',
#  'concepcion del uruguay',
#  'ola',
#  'marataizes',
#  'grindavik',
#  'asau',
#  'morondava',
#  'guadalupe y calvo',
#  'long beach',
#  'sao lourenco do sul',
#  'deputatskiy',
#  'kirovsk',
#  'kasganj',
#  'dikson',
#  'bolungarvik',
#  'narwar',
#  'brae',
#  'bilma',
#  'calama',
#  'markala',
#  'takoradi',
#  'chornobay',
#  'arman',
#  'fuengirola',
#  'eftimie murgu',
#  'sola',
#  'eureka',
#  'yerbogachen',
#  'alofi',
#  'spirit river',
#  'makakilo city',
#  'warqla',
#  'isla mujeres',
#  'lodja',
#  'hoi an',
#  'aykhal',
#  'lermontovka',
#  'havoysund',
#  'marystown',
#  'areka',
#  'pervomayskoye',
#  'bargal',
#  'matamoros',
#  'marau',
#  'honiara',
#  'ambunti',
#  'visnes',
#  'longlac',
#  'alice springs',
#  'windhoek',
#  'tabiauea',
#  'morden',
#  'high river',
#  'camocim',
#  'yulara',
#  'mrirt',
#  'spearfish',
#  'babynino',
#  'freeport',
#  'elbistan',
#  'emba',
#  'mvuma',
#  'lwowek slaski',
#  'tumannyy',
#  'rio gallegos',
#  'merrill',
#  'ilebo',
#  'aksarka',
#  'conceicao do araguaia',
#  'tshikapa',
#  'la rioja',
#  'nalut',
#  'wanaka',
#  'ciudad guayana',
#  'tongchuan',
#  'marawi',
#  'bubaque',
#  'bedford',
#  'trairi',
#  'centralina',
#  'state college',
#  'atbasar',
#  'xining',
#  'callaguip',
#  'shelburne',
#  'westport',
#  'mecca',
#  'yima',
#  'dno',
#  'cockburn town',
#  'urambo',
#  'trincomalee',
#  'tarudant',
#  'krasnokamensk',
#  'santa isabel do rio negro',
#  'hellin',
#  'washington',
#  'corrales',
#  'conakry',
#  'san bartolome de tirajana',
#  'jeremie',
#  'skala']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
len(cities)
# Out:
# 620

# %%
#check if we got the code right
x = requests.get(f'http://api.openweathermap.org/data/2.5/weather?q={cities[0]}&appid={api_key}').json()
pprint(x)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': -2.57, 'lon': 150.8},
#  'dt': 1604771788,
#  'id': 2094342,
#  'main': {'feels_like': 302.79,
#           'grnd_level': 1008,
#           'humidity': 70,
#           'pressure': 1009,
#           'sea_level': 1009,
#           'temp': 301.08,
#           'temp_max': 301.08,
#           'temp_min': 301.08},
#  'name': 'Kavieng',
#  'sys': {'country': 'PG', 'sunrise': 1604777642, 'sunset': 1604821626},
#  'timezone': 36000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 91, 'speed': 4.23}}

# %%
x['coord']['lat']
# Out:
# -2.57

# %%
#Create empty arrays/lists that will for the api call


url = 'api.openweathermap.org/data/2.5/weather?q={city_name}&appid={api_key}'


# city_name = []
# country = []
# date_temp = []
# longitude =[] #always put the long first, this is the x axis!
# latitude = []

# humidity=[] #the bane of my existance!!
# clouds =[]
# max_temp=[]
# winds=[]

pre_df=[]

#the number of given cities is far too long! I will only use 150 as the api only allows 60 calls per second.
#I used the UrlLib.Parse function to take out spaces within the city names, as I was recieving errors

for city in cities:
    
    try:
        response = requests.get(f'http://api.openweathermap.org/data/2.5/weather?q={urllib.parse.quote(city)}&appid={api_key}').json()
        city_name=response['name']
        country=response['sys']['country']
        date_temp = response['dt']
        longitude = response['coord']['lon']
        latitude = response['coord']['lat']
        humidity = response['main']['humidity']
        clouds = response['clouds']['all']
        max_temp = response['main']['temp_max']
        winds = response['wind']['speed']
        
        city_info={
            'City Name': city_name,
            'Country': country,
            'Date':date_temp,
            'Longitude':longitude,
            'Latitude':latitude,
            'Humidity':humidity,
            'Cloud Cover':clouds,
            'Temp K': max_temp,
            'Winds':winds
        }
        
        pre_df.append(city_info)
        print(f'{city} is being appened to list')
        
    except: #if the city we are looking for isn't in the list
        print(f'{city} is not in generated list.' )

print('---------------------------------------------')
print('Complete')
# Out:
# cabo san lucas is being appened to list
# sur is being appened to list
# ust-maya is being appened to list
# svetlogorsk is being appened to list
# lorengau is being appened to list
# kloulklubed is being appened to list
# san patricio is being appened to list
# azangaro is being appened to list
# narsaq is being appened to list
# northam is being appened to list
# tuktoyaktuk is being appened to list
# iskateley is being appened to list
# ushuaia is being appened to list
# kenai is being appened to list
# cape town is being appened to list
# albany is being appened to list
# arraial do cabo is being appened to list
# norman wells is being appened to list
# san juan is being appened to list
# bredasdorp is being appened to list
# punta arenas is being appened to list
# zenzeli is being appened to list
# codrington is being appened to list
# saint-francois is being appened to list
# taolanaro is not in generated list.
# lompoc is being appened to list
# makasar is being appened to list
# luganville is being appened to list
# terrasini is being appened to list
# singleton is being appened to list
# nemuro is being appened to list
# mahebourg is being appened to list
# vaini is being appened to list
# attawapiskat is not in generated list.
# barrow is being appened to list
# mataura is being appened to list
# pechenga is being appened to list
# hermanus is being appened to list
# sembe is being appened to list
# new norfolk is being appened to list
# fortuna is being appened to list
# butaritari is being appened to list
# turayf is being appened to list
# bailen is being appened to list
# hobart is being appened to list
# sibu is being appened to list
# mys shmidta is not in generated list.
# rikitea is being appened to list
# severo-kurilsk is being appened to list
# puerto ayora is being appened to list
# puri is being appened to list
# bluff is being appened to list
# vostok is being appened to list
# angoram is being appened to list
# asyut is being appened to list
# upernavik is being appened to list
# rawannawi is not in generated list.
# kapaa is being appened to list
# tiksi is being appened to list
# ostrovnoy is being appened to list
# saint-philippe is being appened to list
# miri is being appened to list
# mayfield is being appened to list
# port alfred is being appened to list
# bambous virieux is being appened to list
# oriximina is being appened to list
# hofn is being appened to list
# chuy is being appened to list
# chagda is not in generated list.
# kahului is being appened to list
# saint george is being appened to list
# qaanaaq is being appened to list
# east london is being appened to list
# taoudenni is being appened to list
# kaitangata is being appened to list
# victoria is being appened to list
# itarema is being appened to list
# kuopio is being appened to list
# palabuhanratu is not in generated list.
# tillabery is not in generated list.
# viedma is being appened to list
# baglung is being appened to list
# otradnoye is being appened to list
# kualakapuas is being appened to list
# dogondoutchi is being appened to list
# vadlapudi is being appened to list
# qaqortoq is being appened to list
# sudzha is being appened to list
# mixtepec is not in generated list.
# juigalpa is being appened to list
# adrar is being appened to list
# almeirim is being appened to list
# hambantota is being appened to list
# jalu is being appened to list
# port hardy is being appened to list
# puerto escondido is being appened to list
# moose factory is being appened to list
# geraldton is being appened to list
# mahenge is being appened to list
# vankleek hill is being appened to list
# macia is being appened to list
# scarborough is being appened to list
# umzimvubu is not in generated list.
# akyab is being appened to list
# guerrero negro is being appened to list
# laguna is being appened to list
# belen is being appened to list
# obihiro is being appened to list
# yakeshi is being appened to list
# husavik is being appened to list
# sheregesh is being appened to list
# ilulissat is being appened to list
# port augusta is being appened to list
# hansi is being appened to list
# ouesso is being appened to list
# poum is being appened to list
# tunduru is not in generated list.
# sabaudia is being appened to list
# cururupu is being appened to list
# mikuni is being appened to list
# gat is being appened to list
# bereda is being appened to list
# kannad is being appened to list
# puerto penasco is being appened to list
# marsa matruh is being appened to list
# coihaique is being appened to list
# qabis is not in generated list.
# darnah is being appened to list
# rungata is not in generated list.
# price is being appened to list
# evensk is being appened to list
# pangnirtung is being appened to list
# tazovskiy is being appened to list
# deh rawud is not in generated list.
# talaya is being appened to list
# suluq is being appened to list
# fort nelson is being appened to list
# urdzhar is not in generated list.
# salinopolis is being appened to list
# taltal is being appened to list
# loralai is being appened to list
# sao jose da coroa grande is being appened to list
# morant bay is being appened to list
# colares is being appened to list
# wete is being appened to list
# avera is being appened to list
# luderitz is being appened to list
# gizo is being appened to list
# zyryanka is being appened to list
# chandbali is being appened to list
# plouzane is being appened to list
# shirokiy is being appened to list
# tommot is being appened to list
# zholymbet is being appened to list
# broken hill is being appened to list
# santa rosa is being appened to list
# nantucket is being appened to list
# launceston is being appened to list
# sol-iletsk is being appened to list
# novyy urengoy is being appened to list
# airai is being appened to list
# chilca is being appened to list
# malanje is being appened to list
# kuche is not in generated list.
# zhangye is being appened to list
# cayenne is being appened to list
# camapua is being appened to list
# high rock is being appened to list
# chihuahua is being appened to list
# bengkulu is being appened to list
# karaul is not in generated list.
# garwa is being appened to list
# fernley is being appened to list
# meulaboh is being appened to list
# abu kamal is being appened to list
# enshi is being appened to list
# urengoy is being appened to list
# balikpapan is being appened to list
# shingu is being appened to list
# bosobolo is being appened to list
# cascais is being appened to list
# taybad is being appened to list
# yenagoa is being appened to list
# egvekinot is being appened to list
# vardo is being appened to list
# ati is being appened to list
# hilton head island is being appened to list
# vigrestad is being appened to list
# zachagansk is not in generated list.
# hobyo is being appened to list
# helong is being appened to list
# ejutla de crespo is being appened to list
# key largo is being appened to list
# lavrentiya is being appened to list
# beckley is being appened to list
# san rafael is being appened to list
# leningradskiy is being appened to list
# borodino is being appened to list
# vila do maio is being appened to list
# dasoguz is being appened to list
# simao is being appened to list
# pokrovskoye is being appened to list
# luorong is being appened to list
# beyneu is being appened to list
# gornyy is being appened to list
# leshukonskoye is being appened to list
# zaton is being appened to list
# caconde is being appened to list
# merke is being appened to list
# goksun is being appened to list
# trincomalee is being appened to list
# tarudant is not in generated list.
# krasnokamensk is being appened to list
# santa isabel do rio negro is being appened to list
# hellin is being appened to list
# washington is being appened to list
# corrales is being appened to list
# conakry is being appened to list
# san bartolome de tirajana is being appened to list
# jeremie is being appened to list
# skala is being appened to list
# ---------------------------------------------
# Complete

# %%
weather_data=pd.DataFrame(pre_df)

# %%
def subtract_k(x):
    return x - 273

weather_data['Temp'] = weather_data['Temp K'].apply(subtract_k)
weather_data.head(10)
# Out:
#         City Name Country        Date  Longitude  Latitude  Humidity  \
# 0  Cabo San Lucas      MX  1604777035    -109.91     22.89        69
# 1             Sur      OM  1604777246      59.53     22.57        77
# 2        Ust-Maya      RU  1604777246     134.53     60.42        90
# 3    Forsytheganj      BY  1604777246      29.73     52.63        93
# 4        Lorengau      PG  1604776999     147.27     -2.02        75
# 5     Kloulklubed      PW  1604777246     134.26      7.04        94
# 6    San Patricio      US  1604777246     -97.52     28.02        54
# 7        Azángaro      PE  1604776986     -70.22    -14.92        15
# 8          Narsaq      GL  1604777246     -46.05     60.92        74
# 9         Northam      GB  1604777246      -4.22     51.03        93
#
#    Cloud Cover  Temp K  Winds   Temp
# 0           75  302.04   4.60  29.04
# 1            0  297.39   3.21  24.39
# 2          100  252.30   1.66 -20.70
# 3           58  280.94   3.57   7.94
# 4           33  300.43   3.90  27.43
# 5           90  298.15   2.60  25.15
# 6           40  301.15   5.70  28.15
# 7           40  292.15   6.20  19.15
# 8           75  272.15   1.50  -0.85
# 9          100  286.48   0.89  13.48

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_data.dtypes
# Out:
# City Name       object
# Country         object
# Date             int64
# Longitude      float64
# Latitude       float64
# Humidity         int64
# Cloud Cover      int64
# Temp K         float64
# Winds          float64
# Temp           float64
# dtype: object

# %%
weather_data.to_csv('Weather_Report_-_Raw_File.csv')
weather_data.count()
# Out:
# City Name      569
# Country        569
# Date           569
# Longitude      569
# Latitude       569
# Humidity       569
# Cloud Cover    569
# Temp K         569
# Winds          569
# Temp           569
# dtype: int64

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
x_lat = weather_data['Latitude'] #y axis
y_temp = weather_data['Temp'] #x axis

plt.figure(figsize = (7,7))
plt.scatter(x_lat,y_temp)
plt.xlabel('Latitude')
plt.ylabel('Max Temp C')
plt.title('Latitude v Max Temp')
plt.grid()
plt.figure(figsize = (7,7))
plt.savefig('Temp_v_Latitude.png',dpi=220)
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
y_humid = weather_data['Humidity']

plt.figure(figsize =(7,7))
plt.scatter(x_lat, y_humid, facecolor='blue')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Latitude v Humidity')
plt.grid()
plt.savefig('Humidity_v_Lat.png', dpi=220)
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
y_cloud = weather_data['Cloud Cover']

plt.figure(figsize =(7,7))
plt.scatter(x_lat, y_humid, facecolor='grey')
plt.xlabel('Latitude')
plt.ylabel('Cloud Cover (%)')
plt.title('Latitude v Cloud Cover')
plt.grid()
plt.figure(figsize =(7,7))
plt.savefig('CloudCover.png', dpi=220)
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
y_wind= weather_data['Winds']

plt.figure(figsize =(7,7))
plt.scatter(x_lat, y_humid, facecolor='grey')
plt.xlabel('Latitude')
plt.ylabel('WInd Speed (mph)')
plt.title('Latitude v Wind Speed')
plt.grid()
plt.figure(figsize =(7,7))
plt.savefig('Windspeed.png', dpi=220)
plt.show()

# %%
#create north and southern hemispheres
north_hem = weather_data.loc[weather_data['Latitude']>0]
south_hem = weather_data.loc[weather_data['Latitude']<0]

# %%
north_hem.head()
# Out:
#         City Name Country        Date  Longitude  Latitude  Humidity  \
# 0  Cabo San Lucas      MX  1604777035    -109.91     22.89        69
# 1             Sur      OM  1604777246      59.53     22.57        77
# 2        Ust-Maya      RU  1604777246     134.53     60.42        90
# 3    Forsytheganj      BY  1604777246      29.73     52.63        93
# 5     Kloulklubed      PW  1604777246     134.26      7.04        94
#
#    Cloud Cover  Temp K  Winds   Temp
# 0           75  302.04   4.60  29.04
# 1            0  297.39   3.21  24.39
# 2          100  252.30   1.66 -20.70
# 3           58  280.94   3.57   7.94
# 5           90  298.15   2.60  25.15

# %%
latitude = north_hem['Latitude']
temp = north_hem['Temp']

slope, intercept, rvalue, pvalue, stderr, = st.linregress(latitude, temp)
reg_value = slope*latitude + intercept
eqn ='y =' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))
rval = 'r = ' + str(round(rvalue,2))

plt.figure(figsize =(8,8))
plt.scatter(latitude, temp, color ='red')
plt.plot(latitude, reg_value, color = 'black')
plt.annotate(eqn,(8,10), fontsize = 12, color ='black')
plt.annotate(rval,(8, 8), fontsize = 12, color = 'black')
plt.xlabel('Latitude')
plt.ylabel('Temp C')
plt.title('Northern Hemisphere // Temp v Latitude')
plt.savefig('rvalue_north-hem.png', dpi = 220)
plt.show()

# %%
# Southern Hemisphere v Temp
latitude = south_hem['Latitude']
temp = south_hem['Temp']

slope, intercept, rvalue, pvalue, stderr, = st.linregress(latitude, temp)
reg_value = slope*latitude + intercept
eqn ='y =' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))
rval = 'r = ' + str(round(rvalue,2))

plt.figure(figsize =(8,8))
plt.scatter(latitude, temp, color ='red')
plt.plot(latitude, reg_value, color = 'black')
plt.annotate(eqn,(-50,30), fontsize = 12, color ='black')
plt.annotate(rval,(-50,29), fontsize = 12, color = 'black')
plt.xlabel('Latitude')
plt.ylabel('Temp C')
plt.title('Southern Hemisphere // Temp v Latitude')
plt.savefig('rvalue_south-hem.png', dpi = 220)
plt.show()

# %%
#Northern Hemisphere v Humidity

latitude = north_hem['Latitude']
humidity = north_hem['Humidity']

slope, intercept, rvalue, pvalue, stderr, = st.linregress(latitude, humidity)
reg_value = slope*latitude + intercept
eqn ='y =' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))
rval = 'r = ' + str(round(rvalue,2))

plt.figure(figsize =(8,8))
plt.scatter(latitude, humidity, color ='blue')
plt.plot(latitude, reg_value, color = 'black')
plt.annotate(eqn,(60,40), fontsize = 12, color ='black')
plt.annotate(rval,(60,35), fontsize = 12, color = 'black')
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
plt.title('Northern Hemisphere // Humidity v Latitude')
plt.savefig('humidity_north-hem.png', dpi = 220)
plt.show()

# %%
#Southern Hemisphere v Humidity

latitude = south_hem['Latitude']
humidity = south_hem['Humidity']

slope, intercept, rvalue, pvalue, stderr, = st.linregress(latitude, humidity)
reg_value = slope*latitude + intercept
eqn ='y =' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))
rval = 'r = ' + str(round(rvalue,2))

plt.figure(figsize =(8,8))
plt.scatter(latitude, humidity, color ='blue')
plt.plot(latitude, reg_value, color = 'black')
plt.annotate(eqn,(60,40), fontsize = 12, color ='black')
plt.annotate(rval,(60,35), fontsize = 12, color = 'black')
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
plt.title('Northern Hemisphere // Humidity v Latitude')
plt.savefig('humidity_south-hem.png', dpi = 220)
plt.show()

# %%
#Northern Hemisphere v Cloud Cover

latitude = north_hem['Latitude']
cloud_cover = north_hem['Cloud Cover']

slope, intercept, rvalue, pvalue, stderr, = st.linregress(latitude, cloud_cover)
reg_value = slope*latitude + intercept
eqn ='y =' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))
rval = 'r = ' + str(round(rvalue,2))

plt.figure(figsize =(8,8))
plt.scatter(latitude, cloud_cover, color ='grey')
plt.plot(latitude, reg_value, color = 'black')
plt.annotate(eqn,(60,35), fontsize = 12, color ='black')
plt.annotate(rval,(60,30), fontsize = 12, color = 'black')
plt.xlabel('Latitude')
plt.ylabel('Cloud Cover %')
plt.title('Northern Hemisphere // Cloud Cover v Latitude')
plt.savefig('cloud-cover_v-northern-hem.png', dpi = 220)
plt.show()

# %%
#Southern Hemisphere v Cloud Cover

latitude = south_hem['Latitude']
cloud_cover = south_hem['Cloud Cover']

slope, intercept, rvalue, pvalue, stderr, = st.linregress(latitude, cloud_cover)
reg_value = slope*latitude + intercept
eqn ='y =' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))
rval = 'r = ' + str(round(rvalue,2))

plt.figure(figsize =(8,8))
plt.scatter(latitude, cloud_cover, color ='grey')
plt.plot(latitude, reg_value, color = 'black')
plt.annotate(eqn,(-50,35), fontsize = 12, color ='black')
plt.annotate(rval,(-50,30), fontsize = 12, color = 'black')
plt.xlabel('Latitude')
plt.ylabel('Cloud Cover %')
plt.title('Northern Hemisphere // Cloud Cover v Latitude')
plt.savefig('cloud-cover_v-southern-hem.png', dpi = 220)
plt.show()

# %%
#Northern Hemisphere v Wind Speed Kph 

latitude = north_hem['Latitude']
wind_speed = north_hem['Winds']

slope, intercept, rvalue, pvalue, stderr, = st.linregress(latitude, wind_speed)
reg_value = slope*latitude + intercept
eqn ='y =' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))
rval = 'r = ' + str(round(rvalue,2))

plt.figure(figsize =(8,8))
plt.scatter(latitude, wind_speed, color ='lightblue')
plt.plot(latitude, reg_value, color = 'black')
plt.annotate(eqn,(0,15), fontsize = 12, color ='black')
plt.annotate(rval,(0,14), fontsize = 12, color = 'black')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed KpH')
plt.title('Northern Hemisphere // Wind Speed v Latitude')
plt.savefig('wind_v-northern-hem.png', dpi = 220)
plt.show()

# %%
#Southern Hemisphere v Wind Speed Kph 

latitude = south_hem['Latitude']
wind_speed = south_hem['Winds']

slope, intercept, rvalue, pvalue, stderr, = st.linregress(latitude, wind_speed)
reg_value = slope*latitude + intercept
eqn ='y =' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))
rval = 'r = ' + str(round(rvalue,2))

plt.figure(figsize =(8,8))
plt.scatter(latitude, wind_speed, color ='lightblue')
plt.plot(latitude, reg_value, color = 'black')
plt.annotate(eqn,(-50,10), fontsize = 12, color ='black')
plt.annotate(rval,(-50,9.5), fontsize = 12, color = 'black')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed KpH')
plt.title('South Hemisphere // Wind Speed v Latitude')
plt.savefig('wind_v-south-hem.png', dpi = 220)
plt.show()
